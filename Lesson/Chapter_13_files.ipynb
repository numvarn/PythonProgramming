# %%
f = open('./data/somefile.txt', 'w')  

f.write('Hello, ')  
f.write('World!')  
f.close()

# %%
f = open('./news.txt')

# %%
f.read()
# Out:
# '(CNN)Canadian Prime Minister Justin Trudeau apologized Wednesday after a photo emerged of him wearing brownface during a school event in 2001.\n\n"I shouldn\'t have done it. I should have known better, but I didn\'t," he told reporters on an airplane. "And I\'m really sorry."\nHe said it was a racist photo but he didn\'t consider it racist at the time.\n'

# %%
f = open('./data/somefile.txt', 'r')  
f.read(4)
# Out:
# 'Hell'

# %%
f = open('./data/somefile.txt', 'r')  
f.read()
# Out:
# 'Hello, World!'

# %%
with open('./data/pi_digit.txt') as fp:  
    line = fp.readline()
    cnt = 1
    while line:
        print("Line {}: {}".format(cnt, line.strip()))
        line = fp.readline()
        cnt += 1
# Out:
# Line 1: 3.1415926535
# Line 2: 8979323846
# Line 3: 2643383279

# %%
with open('./data/pi_digit.txt') as fp:  
    cnt = 1
    for line in fp:
        print("Line {}: {}".format(cnt, line.strip()))
        cnt += 1
# Out:
# Line 1: 3.1415926535
# Line 2: 8979323846
# Line 3: 2643383279

# %%
data = ["This is 1st line",
        "This is 2nd line",
        "This is 3rd line",
        "This is 4th line",
        "This is 5th line"]

with open('./data/somfile.txt', 'w') as fp:
    for line in data:
        fp.write(line+"\n")
        
with open('./data/somfile.txt', 'r') as fp:  
    line = fp.readline()
    while line:
        print("{}".format(line.strip()))
        line = fp.readline()
# Out:
# This is 1st line
# This is 2nd line
# This is 3rd line
# This is 4th line
# This is 5th line

# %%
import os
def print_dir(dir_path):
    for name in os.listdir(dir_path):
        print(os.path.join(dir_path, name))

# %%
def print_tree(dir_path):
    for name in os.listdir(dir_path):
        full_path = os.path.join(dir_path, name) 
        print (full_path)
        if os.path.isdir(full_path):
            print_tree(full_path)

# %%
print_tree('/Users/phisan/ResearchCode')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-57-0ec907c1f3cd> in <module>()
# ----> 1 os.listdir('/Users/phisan/ResearchCode')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/phisan/ResearchCode'

# %%
import csv
 
with open('./data/file.csv') as csvDataFile:
    csvReader = csv.reader(csvDataFile)
    for row in csvReader:
        print(row)
# Out:
# ['01/01/2016', ' 4']
# ['02/01/2016', ' 2']
# ['03/01/2016', ' 10']
# ['04/01/2016', ' 8']

# %%
import csv
 
dates = []
scores = []
 
with open('./data/file.csv') as csvDataFile:
    csvReader = csv.reader(csvDataFile)
    for row in csvReader:
        dates.append(row[0])
        scores.append(row[1])
 
print(dates)
print(scores)
# Out:
# ['01/01/2016', '02/01/2016', '03/01/2016', '04/01/2016']
# [' 4', ' 2', ' 10', ' 8']

# %%
import csv
 
myData = [["first_name", "second_name", "Grade"],
          ['Alex', 'Brian', 'A'],
          ['Tom', 'Smith', 'B']]
 
with open('example2.csv', 'w') as myFile:
    writer = csv.writer(myFile)
    writer.writerows(myData)
     
print("Writing complete")
# Out:
# Writing complete

# %%
full_path = 'C:\\Program Files\\Python24\\Lib\\test.txt'
path, filename = os.path.split(full_path)
print(filename)
# Out:
# 01SymptomWordList.py
